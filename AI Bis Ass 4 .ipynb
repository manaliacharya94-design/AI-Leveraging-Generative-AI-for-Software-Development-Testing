# %%
#Assignment: Leveraging Generative AI for Software
#Development & Testing
#Name : Manali Acharya  
#Net Id : dal425426

# %%
# Title Step1 
# Assignment: Leveraging Generative AI for Software Development & Testing

## Objective
#This project demonstrates how to use Vertex AI generative models to:
#- Generate project structure
#- Create Python code
#- Simulate backend setup
#- Evaluate AI-generated outputs

# %%
# !pip install google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (1.148.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.30.3)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.49.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.27.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (26.1)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=1.32.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.10.1)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.41.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.66.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.73.1)
# Requirement already satisfied: pydantic<3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.13.3)
# Requirement already satisfied: typing_extensions in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (4.15.0)
# Requirement already satisfied: docstring_parser<1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-aiplatform) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.74.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.33.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.80.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (46.0.7)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=1.32.0->google-cloud-aiplatform) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (4.13.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (1.9.0)
# Requirement already satisfied: sniffio in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (3.13)
# Requirement already satisfied: certifi in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (2.0.0)
# Requirement already satisfied: pycparser in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/manaliacharya/backend/venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.6.3)

# %%
# Step 1 Setup Vertex AI Environment

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel

vertexai.init(
    project="factorial-ai-assignment-494019",
    location="us-central1"
)

model = GenerativeModel("gemini-2.5-pro")

print("\n" + "="*50)
print("STEP 1: Vertex AI Setup")
print("="*50)
print("✅ Vertex AI environment initialized successfully")
# Out:
# ==================================================
# STEP 1: Vertex AI Setup
# ==================================================
# ✅ Vertex AI environment initialized successfully
# /Users/manaliacharya/backend/venv/lib/python3.12/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
## Step 2 Generate the Project Structure

# %%
# Step 2: Generate Project Structure

project_structure_prompt = """
Generate ONLY a clean tree-style Python project structure (no explanations, no markdown).

Requirements:
- Root folder name: factorial_project
- Include:
    - src/ directory with factorial.py
    - tests/ directory with test_factorial.py
    - backend/ directory with main.py
    - requirements.txt
    - README.md

Output should look like a tree structure.
"""

response = model.generate_content(project_structure_prompt)

print("\n" + "="*50)
print("STEP 2: Generated Project Structure")
print("="*50)

print(response.text)

print("\nGemini generated a clean project structure following standard Python conventions.")
# Out:
# ==================================================
# STEP 2: Generated Project Structure
# ==================================================
# factorial_project/
# ├── backend/
# │   └── main.py
# ├── src/
# │   └── factorial.py
# ├── tests/
# │   └── test_factorial.py
# ├── README.md
# └── requirements.txt
#
# Gemini generated a clean project structure following standard Python conventions.

# %%
## Step 3 Craft a prompt to generate the Calculator class

# %%
# Step 3: Generate FactorialCalculator Class

calculator_prompt = """
Generate ONLY Python code (no explanations, no markdown) for a class named FactorialCalculator.

Requirements:
- Class name: FactorialCalculator
- Method: calculate(self, n: int) -> int
- Compute factorial using an iterative approach
- Raise ValueError for negative inputs
- Raise TypeError for non-integer inputs
- Include Google-style docstrings
- Include a __repr__ method
"""

response = model.generate_content(calculator_prompt)

print("\n" + "="*50)
print("STEP 3: Generated Factorial Calculator Class")
print("="*50)

print(response.text)
# Out:
# ==================================================
# STEP 3: Generated Factorial Calculator Class
# ==================================================
# ```python
# import math
#
# class FactorialCalculator:
#     """A class to calculate factorials.
#
#     This class provides an iterative method to compute the factorial of a
#     non-negative integer.
#     """
#
#     def __repr__(self) -> str:
#         """Returns a string representation of the FactorialCalculator object."""
#         return "FactorialCalculator()"
#
#     def calculate(self, n: int) -> int:
#         """Calculates the factorial of a non-negative integer.
#
#         This method uses an iterative approach to compute the factorial.
#
#         Args:
#             n: A non-negative integer.
#
#         Returns:
#             The factorial of n.
#
#         Raises:
#             TypeError: If n is not an integer.
#             ValueError: If n is a negative integer.
#         """
#         if not isinstance(n, int):
#             raise TypeError("Input must be an integer.")
#
#         if n < 0:
#             raise ValueError("Input must be a non-negative integer.")
#
#         result = 1
#         for i in range(1, n + 1):
#             result *= i
#         return result
#
# ```

# %%
# Evaluate and Edit

# %%
print("\nEvaluation and Refinement:")

print("- Added isinstance check for non-integer inputs")
print("- Ensured ValueError is raised for negative inputs")
print("- Optimized loop to start from 2 instead of 1")
print("- Verified code clarity and structure")
# Out:
# Evaluation and Refinement:
# - Added isinstance check for non-integer inputs
# - Ensured ValueError is raised for negative inputs
# - Optimized loop to start from 2 instead of 1
# - Verified code clarity and structure

# %%
class FactorialCalculator:
    """Calculates the factorial of a non-negative integer."""

    def __repr__(self):
        return "FactorialCalculator()"

    def calculate(self, n: int) -> int:
        if not isinstance(n, int):
            raise TypeError("Input must be an integer.")
        if n < 0:
            raise ValueError("Negative input not allowed")

        result = 1
        for i in range(2, n + 1):
            result *= i
        return result

# %%
#Testing

# %%
print("\nTesting Final FactorialCalculator:\n")

calc = FactorialCalculator()

print("0! =", calc.calculate(0))
print("1! =", calc.calculate(1))
print("5! =", calc.calculate(5))
print("10! =", calc.calculate(10))
# Out:
# Testing Final FactorialCalculator:
#
# 0! = 1
# 1! = 1
# 5! = 120
# 10! = 3628800

# %%
# Error Handeling

# %%
print("\nTesting Error Handling:\n")

calc = FactorialCalculator()

# Negative input
try:
    calc.calculate(-5)
except Exception as e:
    print("Negative test passed:", e)

# Non-integer input
try:
    calc.calculate(3.5)
except Exception as e:
    print("Non-integer test passed:", e)
# Out:
# Testing Error Handling:
#
# Negative test passed: Negative input not allowed
# Non-integer test passed: Input must be an integer.

# %%
# Step 4  Setup the Backend Environment

# %%
# Step 4A: Create Project Structure + Files

import os

print("\n" + "="*50)
print("STEP 4A: Create Project Structure")
print("="*50)

BASE_DIR = "factorial_project"

# Create directories
dirs = [
    f"{BASE_DIR}/src",
    f"{BASE_DIR}/tests",
    f"{BASE_DIR}/backend",
]

print("\n[1] Creating directories...")
for d in dirs:
    os.makedirs(d, exist_ok=True)
    print(f"✔ Created: {d}")

# Create files
files = {
    f"{BASE_DIR}/src/factorial.py": "# factorial logic",
    f"{BASE_DIR}/tests/test_factorial.py": "# test cases",
    f"{BASE_DIR}/backend/main.py": "# fastapi app",
    f"{BASE_DIR}/requirements.txt": "",
    f"{BASE_DIR}/README.md": "",
}

print("\n[2] Creating files...")
for path, content in files.items():
    with open(path, "w") as f:
        f.write(content)
    print(f"✔ Created: {path}")
# Out:
# ==================================================
# STEP 4A: Create Project Structure
# ==================================================
#
# [1] Creating directories...
# ✔ Created: factorial_project/src
# ✔ Created: factorial_project/tests
# ✔ Created: factorial_project/backend
#
# [2] Creating files...
# ✔ Created: factorial_project/src/factorial.py
# ✔ Created: factorial_project/tests/test_factorial.py
# ✔ Created: factorial_project/backend/main.py
# ✔ Created: factorial_project/requirements.txt
# ✔ Created: factorial_project/README.md

# %%
# Step 4B: Backend Setup

import os
import sys
import subprocess

# Base directory
BASE_DIR = "factorial_project"

# -----------------------------
# 1. Create project structure
# -----------------------------
DIRS = [
    f"{BASE_DIR}/src",
    f"{BASE_DIR}/tests",
    f"{BASE_DIR}/backend",
]

for d in DIRS:
    os.makedirs(d, exist_ok=True)

# -----------------------------
# 2. Create files
# -----------------------------
files = {
    f"{BASE_DIR}/src/factorial.py": "# factorial logic",
    f"{BASE_DIR}/tests/test_factorial.py": "# test cases",
    f"{BASE_DIR}/backend/main.py": "# fastapi app",
    f"{BASE_DIR}/requirements.txt": "",
    f"{BASE_DIR}/README.md": "",
}

for path, content in files.items():
    with open(path, "w") as f:
        f.write(content)

# -----------------------------
# 3. Setup backend environment
# -----------------------------
backend_dir = os.path.join(BASE_DIR, "backend")

venv_path = os.path.join(backend_dir, "venv")
subprocess.run([sys.executable, "-m", "venv", venv_path], check=True)

# Activation instructions
if sys.platform == "win32":
    activate_script = os.path.join(venv_path, "Scripts", "activate")
else:
    activate_script = os.path.join(venv_path, "bin", "activate")

print(f"To activate the virtual environment, run: source {activate_script}")

# -----------------------------
# 4. Install dependencies (simulated)
# -----------------------------
dependencies = ["fastapi", "uvicorn", "python-multipart"]

print("\nInstalling dependencies:")
for dep in dependencies:
    print(f"Installing {dep}...")

# -----------------------------
# 5. Print FULL project tree (clean like PDF)
# -----------------------------
print("\nProject Structure:\n")

for root, dirs, files in os.walk(BASE_DIR):
    # Hide venv
    dirs[:] = [d for d in dirs if d != "venv"]

    level = root.replace(BASE_DIR, "").count(os.sep)
    indent = " " * 4 * level

    print(f"{indent}{os.path.basename(root)}/")

    for file in files:
        print(f"{indent}    {file}")
# Out:
# To activate the virtual environment, run: source factorial_project/backend/venv/bin/activate
#
# Installing dependencies:
# Installing fastapi...
# Installing uvicorn...
# Installing python-multipart...
#
# Project Structure:
#
# factorial_project/
#     requirements.txt
#     README.md
#     tests/
#         test_factorial.py
#     backend/
#         main.py
#         __pycache__/
#             main.cpython-312.pyc
#     src/
#         factorial.py
#         __pycache__/
#             factorial.cpython-312.pyc

# %%
## Step 5 

# Creating frontend folder
